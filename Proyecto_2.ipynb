# %% [markdown]
# <a href="https://colab.research.google.com/github/matvid/Proyecto-2/blob/main/Proyecto_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Importar librerías generales
import numpy as np
import pandas as pd

# %% [markdown]
# # **Primera opción: conjunto de datos 1**
#
# ### *In Hospital Mortality Prediction*

# %%
filename1 = ("/content/drive/MyDrive/Bootcamp/Coding Dojo/Proyecto 2/Data/opcion1.csv")
df1 = pd.read_csv(filename1)

# %%
df1.head()
# Out:
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047      0.0   72        1  37.588179             0
# 1      1  139812      0.0   75        2        NaN             0
# 2      1  109787      0.0   83        2  26.572634             0
# 3      1  130587      0.0   43        2  83.264629             0
# 4      1  138290      0.0   75        2  31.824842             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                   0               0         1  ...    138.750000
# 1                   0               0         0  ...    138.888889
# 2                   0               0         0  ...    140.714286
# 3                   0               0         0  ...    138.500000
# 4                   0               0         0  ...    136.666667
#
#    Blood calcium    Chloride  Anion gap  Magnesium ion     PH  Bicarbonate  \
# 0       7.463636  109.166667  13.166667       2.618182  7.230    21.166667
# ...

# %%
df1.tail()
# Out:
#       group      ID  outcome  age  gendera        BMI  hypertensive  \
# 1172      2  171130      0.0   62        1  25.516870             1
# 1173      2  101659      0.0   78        1  25.822710             0
# 1174      2  162069      0.0   85        2  23.891779             1
# 1175      2  120967      0.0   79        2  35.288554             0
# 1176      2  107636      0.0   47        1  23.121384             1
#
#       atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 1172                   1               0         1  ...    136.714286
# 1173                   1               0         1  ...    135.680000
# 1174                   1               0         1  ...    136.000000
# 1175                   0               1         1  ...    140.000000
# 1176                   0               0         1  ...    135.285714
#
#       Blood calcium    Chloride  Anion gap  Magnesium ion  PH  Bicarbonate  \
# ...

# %%
df1.shape
print(f"El dataframe consta de", df1.shape[0], "filas y", df1.shape[1], "columnas.")
# Out:
# El dataframe consta de 1177 filas y 51 columnas.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   group                     1177 non-null   int64
#  1   ID                        1177 non-null   int64
#  2   outcome                   1176 non-null   float64
#  3   age                       1177 non-null   int64
#  4   gendera                   1177 non-null   int64
#  5   BMI                       962 non-null    float64
#  6   hypertensive              1177 non-null   int64
#  7   atrialfibrillation        1177 non-null   int64
#  8   CHD with no MI            1177 non-null   int64
#  9   diabetes                  1177 non-null   int64
#  10  deficiencyanemias         1177 non-null   int64
#  11  depression                1177 non-null   int64
#  12  Hyperlipemia              1177 non-null   int64
#  13  Renal failure             1177 non-null   int64
# ...

# %% [markdown]
# ### **1) Fuente de datos**

# %% [markdown]
# Kaggle: https://www.kaggle.com/datasets/saurabhshahane/in-hospital-mortality-prediction
#
# El conjunto de datos proviene de la base de datos MIMIC-III, que es una base de datos de pacientes hospitalizados en el Hospital Beth Israel Deaconess Medical Center de Boston, Massachusetts.

# %% [markdown]
# ### **2) Breve descripción de datos**

# %% [markdown]
# El conjunto de datos contiene información sobre pacientes hospitalizados, incluidos sus datos demográficos, médicos y de laboratorio.
#
# Por lo anterior, es necesario revisar predictores de mortalidad hospitalaria de pacientes con insuficiencia cardíaca ingresados ​​en UCI.

# %% [markdown]
# ### **3) ¿Cuál es el objetivo?**

# %% [markdown]
# El objetivo es predecir si un paciente morirá en el Hospital Beth Israel Deaconess Medical Center de Boston, Massachusetts.

# %% [markdown]
# ### **4) ¿Este es un problema de clasificación o regresión?**

# %% [markdown]
# Este es un problema de clasificación binaria, ya que el objetivo es predecir si un paciente morirá o no.

# %% [markdown]
# ### **5) ¿Cuántas características hay?**

# %% [markdown]
# El conjunto de datos contiene 51 características.

# %% [markdown]
# ### **6) ¿Cuántas filas de datos hay?**

# %% [markdown]
# El conjunto de datos contiene 1.177 filas de datos.

# %% [markdown]
# ### **7) ¿Qué retos, si es que hay alguno, prevén en la limpieza, exploración o modelización con este conjunto de datos?**

# %% [markdown]
# Algunos retos que se pueden prever en la limpieza, exploración o modelización con este conjunto de datos son:
#
# - Ausencias de datos: El conjunto de datos contiene algunas ausencias de datos, lo que puede dificultar la limpieza y el análisis.
# - Datos sesgados: El conjunto de datos puede estar sesgado, ya que se basa en datos de pacientes hospitalizados en un único hospital.
# - Dificultad de interpretación: Algunas de las características del conjunto de datos pueden ser difíciles de interpretar, lo que puede dificultar la selección de características y el modelado.
#
# En general, este es un conjunto de datos complejo que presenta algunos retos. Sin embargo, también es un conjunto de datos valioso que puede utilizarse para mejorar la predicción de la mortalidad hospitalaria.

# %% [markdown]
# # **Segunda opción: conjunto de datos 2**

# %%
filename2 = ("/content/drive/MyDrive/Bootcamp/Coding Dojo/Proyecto 2/Data/opcion2.csv")
df2 = pd.read_csv(filename2)

# %%
df2.head()
# Out:
#    Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 0  Turkiye     Middle East  2015           11.1               13.0
# 1    Spain  European Union  2015            2.7                3.3
# 2    India            Asia  2007           51.5               67.9
# 3   Guyana   South America  2006           32.8               40.5
# 4   Israel     Middle East  2012            3.4                4.3
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0         105.8240                 1.32           97       65  27.8  ...
# 1          57.9025                10.35           97       94  26.0  ...
# 2         201.0765                 1.57           60       35  21.2  ...
# 3         222.1965                 5.68           93       74  25.3  ...
# 4          57.9510                 2.89           97       89  27.0  ...
#
#    Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# ...

# %%
df2.tail()
# Out:
#         Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 2859      Niger          Africa  2000           97.0              224.9
# 2860   Mongolia            Asia  2009           23.9               28.6
# 2861  Sri Lanka            Asia  2004           17.7               28.9
# 2862  Lithuania  European Union  2002            7.9                9.9
# 2863    Iceland  Rest of Europe  2011            2.1                2.6
#
#       Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 2859         291.8240                0.092           72       64  20.8  ...
# 2860         235.2330                6.560           97       97  25.3  ...
# 2861         134.8950                1.560           62       95  21.9  ...
# 2862         204.0120               11.000           94       95  26.1  ...
# 2863          50.5745                6.840           88       90  26.1  ...
#
#       Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# ...

# %%
df2.shape
print(f"El dataframe consta de", df2.shape[0], "filas y", df2.shape[1], "columnas.")
# Out:
# El dataframe consta de 2864 filas y 21 columnas.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2864 entries, 0 to 2863
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      2864 non-null   object
#  1   Region                       2864 non-null   object
#  2   Year                         2864 non-null   int64
#  3   Infant_deaths                2864 non-null   float64
#  4   Under_five_deaths            2864 non-null   float64
#  5   Adult_mortality              2864 non-null   float64
#  6   Alcohol_consumption          2864 non-null   float64
#  7   Hepatitis_B                  2864 non-null   int64
#  8   Measles                      2864 non-null   int64
#  9   BMI                          2864 non-null   float64
#  10  Polio                        2864 non-null   int64
#  11  Diphtheria                   2864 non-null   int64
#  12  Incidents_HIV                2864 non-null   float64
# ...

# %% [markdown]
# ### **1) Fuente de datos**

# %% [markdown]
# Kaggle: https://www.kaggle.com/datasets/lashagoch/life-expectancy-who-updated
#
# El conjunto de datos proviene de la Organización Mundial de la Salud (OMS).

# %% [markdown]
# ### **2) Breve descripción de datos**

# %% [markdown]
# El conjunto de datos contiene información sobre la esperanza de vida al nacer para hombres y mujeres en 2022. Los datos se presentan por país, región y grupo de edad. Esto puede proporcionar una panorámica detallada de múltiples indicadores claves, permitiendo así, identificar tendencias de salud.

# %% [markdown]
# ### **3) ¿Cuál es el objetivo?**

# %% [markdown]
# El objetivo es predecir información sobre la esperanza de vida al nacer en todo el mundo.

# %% [markdown]
# ### **4) ¿Este es un problema de clasificación o regresión?**

# %% [markdown]
# Este es un problema de regresión, ya que el objetivo es predecir un valor numérico, la esperanza de vida.

# %% [markdown]
# ### **5) ¿Cuántas características hay?**

# %% [markdown]
# El conjunto de datos contiene 21 características.

# %% [markdown]
# ### **6) ¿Cuántas filas de datos hay?**

# %% [markdown]
# El conjunto de datos contiene 2.864 filas de datos.

# %% [markdown]
# ### **7) ¿Qué retos, si es que hay alguno, prevén en la limpieza, exploración o modelización con este conjunto de datos?**

# %% [markdown]
# Algunos retos que se pueden prever en la limpieza, exploración o modelización con este conjunto de datos son:
#
# - Dificultad de interpretación: Algunas de las características del conjunto de datos pueden ser difíciles de interpretar, lo que puede dificultar la selección de características y el modelado.
